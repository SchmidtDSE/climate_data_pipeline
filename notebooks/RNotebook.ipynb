# %%
#load libs
library(tidyverse)
file_path <- "dataForRScrtips/test_data.csv"

#get data from csv
df <- read_csv(file_path)

#print to ensure loading nad look
print(df)

# ggplot
ggplot(df, aes(x =x, y = y)) +
  geom_point(color = "#0072B2", size = 3) +  
  geom_line(color = "#D55E00", linetype = "dashed") + 
  labs(
    title = "Test ggplot Plot in R",subtitle = "Successfully loaded from CSV",x = "X axis",
    y ="Y xais"
  ) +theme_minimal()
# Out:
# Rows: 10 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): x, y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 10 × 2
#        x     y
#    <dbl> <dbl>
#  1     1     5
#  2     2     7
#  3     3     6
#  4     4     8
#  5     5    10
#  6     6     9
#  7     7    11
#  8     8    13
#  9     9    12
# 10    10    15
# plot without title
