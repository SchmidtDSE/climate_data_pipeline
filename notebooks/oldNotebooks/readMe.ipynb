# %% [markdown]
# ### How/Why to traverse the old notebooks section

# %% [markdown]
# Essentially we've seen that AI does a terrible job at helping one in debugging efforts, therefore, I've included old notebooks that work, such that if one is trying to debug with AI, perhaps the presence of notebooks with working code, may help an LLM 'see' working code, with comments on common bugs, and then help the user in their efforts. Also, if one is trying to create a particulat plot this readMe serves as a guide for where to find the corresponding code.

# %% [markdown]
# #### If you desire graphs that look like this:
#
# ![Joshua Tree Temperature Plot](../../notebooks/OutputImages/JoshuaTree_Statistical_3km_Tavg_TimeSeries.png)
#  #### Then use temperatureAndPrecipAnomoliesToCSV.ipynb, with its corrresponding plotter: temperatureAndPrecipAnomoliesToCsvPLotter.ipynb

# %% [markdown]
# #### If you desire plots that look like:
#
# ![Joshua Tree Temperature Plot](../../notebooks/OutputImages/Seasonal_Precipitation_Anomalies.png)
#
# #### Head over to: "variousSpatialPLots.ipynb"

# %% [markdown]
# #### If you desire seasonal plots, or python scripts that create seasonal csv's to get plots similar to:
#
# ![Joshua Tree Temperature Plot](../../notebooks/OutputImages/MoreOutputImages/Seasonal_Precip_Anomalies_Smooth.png)
#
# #### Head over to and use seaonalToCsv.ipynb and seaonalToCsv2.ipynb with their corresponding R plotters.
